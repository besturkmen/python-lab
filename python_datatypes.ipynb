# %% [markdown]
# <a href="https://colab.research.google.com/github/besturkmen/python-lab/blob/main/python_datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Print komutu ve kullanımı

# %%
print("Hello \nBeste")
print("Hello"+" "+"Beste")
print("Ben \tBeste")
# Out:
# Hello
# Beste
# Hello Beste
# Ben 	Beste

# %%
print("Benim adım {}".format('Beste'))
print("Benim adım {}, yasim {}".format('Beste', 29))

print("Benim adım {0}, yasim {1}".format('Beste', 29))
print("Benim adım {1}, yasim {0}".format('Beste', 29))

print("Benim adım {ad}, yasim {yas}".format(ad='Beste', yas=29))
# Out:
# Benim adım Beste
# Benim adım Beste, yasim 29
# Benim adım Beste, yasim 29
# Benim adım 29, yasim Beste
# Benim adım Beste, yasim 29

# %% [markdown]
# **Değişken ve Atama**
#
# Kabul edilmeyen değişken isim atama senaryoları:
#
#
# *   Sayı ile başlamak
# *   boşluk içermek
#
#
# *   "*(/ gibi semboller içermek
# *   rezerve edilmiş isimleri kullanmak

# %%
sayi=10
print(sayi)
# Out:
# 10

# %%
sayi=11
print(sayi)
# Out:
# 11

# %%
sayi=sayi +1
print(sayi)
sayi=sayi -1
print(sayi)
sayi=sayi *2
print(sayi)
sayi=sayi /5
print(sayi)
# Out:
# 12
# 11
# 22
# 4.4

# %% [markdown]
# # **Veri Tipleri ve Sayı Tipleri (Integer ve Float)**
#
# **Sayilar**
#
#
# *   int: Tam Sayilar
# *   float: Ondalik Sayilar

# %%
type(3)
# Out:
# int

# %%
type(1.5)
# Out:
# float

# %% [markdown]
# **Aritmetik Operasyonlar**

# %%
3+4
# Out:
# 7

# %%
5%3
# Out:
# 2

# %%
10-2
# Out:
# 8

# %%
print(3*4)
print(52%6)
# Out:
# 12
# 4

# %%
3+2*4
# Out:
# 11

# %%
3.1 *2.0
# Out:
# 6.2

# %%
4.1*5
# Out:
# 20.5

# %% [markdown]
# **Yazilar**
#
#
#  P  |  Y  |  T  |  H  |  O  |  N
# _________________________________
#  0  |  1  |  2  |  3  |  4  |  5
#  0  | -5  | -4  | -3  | -2  | -1

# %%
strvar = "Phyton"
print(strvar)
print(strvar[0])
print(strvar[1])
print(strvar[2])
print(strvar[3])
print(strvar[4])
print(strvar[5])
print(strvar[-1])
print(strvar[-2])
print(strvar[-3])
print(strvar[-4])
print(strvar[-5])
print(strvar[-6])
print(strvar[2:])
print(strvar[2:3])
#[] tek eleman alınır
#[:] başlangıç ve bitiş arasındaki elemanlar alınır
#[::] başlangıç ve bitiş arasındaki elemanlar üçüncü kısımdaki değer kadar atlayarak alınır
print(strvar[::2])
print(strvar[::-2])
# Out:
# Phyton
# P
# h
# y
# t
# o
# n
# n
# o
# t
# y
# h
# P
# yton
# y
# Pyo
# nth

# %%
len(strvar)
# Out:
# 6

# %%
strvar =strvar + " oğren!"
strvar
# Out:
# 'Phyton oğren!'

# %%
strvar*5
# Out:
# 'Phyton oğren!Phyton oğren!Phyton oğren!Phyton oğren!Phyton oğren!'

# %%
strvar
# Out:
# 'Phyton oğren!'

# %%
print(strvar.upper())
print(strvar.lower())
print(strvar.split())
print(strvar.split("o"))
print(strvar.split(sep="o", maxsplit=1))
# Out:
# PHYTON OĞREN!
# phyton oğren!
# ['Phyton', 'oğren!']
# ['Phyt', 'n ', 'ğren!']
# ['Phyt', 'n oğren!']

# %% [markdown]
# **Boolean**

# %%
a = True
print(type(a))
b = False
print(a)
print(b)
c = 'True'
print(c)
print(type(c))
# Out:
# <class 'bool'>
# True
# False
# True
# <class 'str'>

# %%
yas1 = 20
yas2 = 18

print(yas2 > 18)
# Out:
# False

# %%
yas2 == 18
# Out:
# True

# %%
yas2 != 18
# Out:
# False

# %%
not yas2 == 18
# Out:
# False

# %%
not yas2 > 18
# Out:
# True

# %% [markdown]
# # **list & set**
# [a  ,  b  ,  c  ,  d  ,  e  ,  a]
# _________________________________
#  0  |  1  |  2  |  3  |  4  |  5
#  0  | -5  | -4  | -3  | -2  | -1

# %%
liste = ['a','b','c','d','e','a']
print(liste)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'a']

# %%
liste = liste + ['f']
liste
# Out:
# ['a', 'b', 'c', 'd', 'e', 'a', 'f']

# %%
liste[0]
# Out:
# 'a'

# %%
liste[3:5]
# Out:
# ['d', 'e']

# %%
liste.append('g')
liste
# Out:
# ['a', 'b', 'c', 'd', 'e', 'a', 'f', 'g']

# %%
liste.pop() # son eklenen elemanı kaldırır
liste
# Out:
# ['a', 'b', 'c', 'd', 'e', 'a', 'f']

# %%
liste.pop(5)
print(liste)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
sayilar = [123,12345,123131,3212,45435,35,1,1]
sayilar.sort() # sıralama yapar

# %%
sayilar
# Out:
# [1, 1, 35, 123, 3212, 12345, 45435, 123131]

# %%
sayilar.reverse() # ters sıralama yapar
print(sayilar)
# Out:
# [123131, 45435, 12345, 3212, 123, 35, 1, 1]

# %%
set(sayilar)
# Out:
# {1, 35, 123, 3212, 12345, 45435, 123131}

# %% [markdown]
# # **tuple**
# (a  ,  b  ,  c  ,  d  ,  e  ,  a)
# _________________________________
#  0  |  1  |  2  |  3  |  4  |  5
#  0  | -5  | -4  | -3  | -2  | -1

# %%
liste = ['a','b','c','d','e','a']
print(liste)
tup = ( 'a','b','c','d','e','a' )
print(tup)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'a']
# ('a', 'b', 'c', 'd', 'e', 'a')

# %%
liste[0] = 12312
liste
# Out:
# [12312, 'b', 'c', 'd', 'e', 'a']

# %%
tup[0] = 12312
tup
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_966/3796614761.py in <cell line: 0>()
# ----> 1 tup[0] = 12312
#       2 tup
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup.count( 'a' )
# Out:
# 2

# %%
tup.count( 'b' )
# Out:
# 1

# %%
tup.count(True)
# Out:
# 0

# %%
tup.index( 'b' ) # kaçıncı indexte yer aldığını söyler
# Out:
# 1

# %%
tup.index( 'a' ) # birkaç tane a bulunsa bile ilk değerin indexini verir
# Out:
# 0

# %%
tup.index(True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_966/2996090797.py in <cell line: 0>()
# ----> 1 tup.index(True)
#
# ValueError: tuple.index(x): x not in tuple

# %% [markdown]
# # **Dictionary**

# %%
dict1 = {'isim': 'Mesut', 'yas':32, 'lokasyon': 'Berlin'}
dict1
# Out:
# {'isim': 'Mesut', 'yas': 32, 'lokasyon': 'Berlin'}

# %%
dict2 = {
    'isim': 'Mesut',
    'yas': 32,
    'dogdugu_sehir': 'Istanbul',
    'yasadigi_sehir': 'Berlin' # yasadigi sehir bilgisi
    ##'lokasyon':
}
dict2
# Out:
# {'isim': 'Mesut',
#  'yas': 32,
#  'dogdugu_sehir': 'Istanbul',
#  'yasadigi_sehir': 'Berlin'}

# %%
dict3 = {
    'isim': 'Mesut',
    'yas': 32,
    'lokasyon': {
        'dogdugu_sehir': 'Istanbul',
        'yasadigi_sehir': 'Berlin'
    }
}
dict3
# Out:
# {'isim': 'Mesut',
#  'yas': 32,
#  'lokasyon': {'dogdugu_sehir': 'Istanbul', 'yasadigi_sehir': 'Berlin'}}

# %%
dict2['yas']
# Out:
# 32

# %%
dict2.get('yas')
# Out:
# 32

# %%
dict3['lokasyon']['yasadigi_sehir']
# Out:
# 'Berlin'

# %%
dict2.keys()
# Out:
# dict_keys(['isim', 'yas', 'dogdugu_sehir', 'yasadigi_sehir'])

# %%
dict2.values()
# Out:
# dict_values(['Mesut', 32, 'Istanbul', 'Berlin'])

# %%
dict2.items()
# Out:
# dict_items([('isim', 'Mesut'), ('yas', 32), ('dogdugu_sehir', 'Istanbul'), ('yasadigi_sehir', 'Berlin')])
